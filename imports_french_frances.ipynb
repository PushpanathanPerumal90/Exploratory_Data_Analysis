# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pandas_profiling

# %%
data=pd.read_csv(r'C:\Users\Hp\Desktop\DATASET NEW\Excel\imports_french_frances.csv')

# %%
data
# Out:
#     Index  Year  One  International Production  Stock  DomesticConsumption  \
# 0       1  1949    1                     149.3    4.2                108.1
# 1       2  1950    1                     161.2    4.1                114.8
# 2       3  1951    1                     171.5    3.1                123.2
# 3       4  1952    1                     175.5    3.1                126.9
# 4       5  1953    1                     180.8    1.1                132.1
# 5       6  1954    1                     190.7    2.2                137.7
# 6       7  1955    1                     202.1    2.1                146.0
# 7       8  1956    1                     212.4    5.6                154.1
# 8       9  1957    1                     226.1    5.0                162.3
# 9      10  1958    1                     231.9    5.1                164.3
# 10     11  1959    1                     239.0    0.7                167.6
# ...

# %%
data.drop(['Index','One'],axis=1,inplace=True)

# %%
data
# Out:
#     Year  International Production  Stock  DomesticConsumption  Imports
# 0   1949                     149.3    4.2                108.1     15.9
# 1   1950                     161.2    4.1                114.8     16.4
# 2   1951                     171.5    3.1                123.2     19.0
# 3   1952                     175.5    3.1                126.9     19.1
# 4   1953                     180.8    1.1                132.1     18.8
# 5   1954                     190.7    2.2                137.7     20.4
# 6   1955                     202.1    2.1                146.0     22.7
# 7   1956                     212.4    5.6                154.1     26.5
# 8   1957                     226.1    5.0                162.3     28.1
# 9   1958                     231.9    5.1                164.3     27.6
# 10  1959                     239.0    0.7                167.6     26.3
# 11  1960                     258.0    5.6                176.8     31.1
# ...

# %%
data.isna().sum()
# Out:
# Year                        0
# International Production    0
# Stock                       0
# DomesticConsumption         0
# Imports                     0
# dtype: int64

# %%
data.unstack()
# Out:
# Year     0     1949.0
#          1     1950.0
#          2     1951.0
#          3     1952.0
#          4     1953.0
#                 ...
# Imports  13      37.0
#          14      43.3
#          15      49.0
#          16      50.3
#          17      56.6
# Length: 90, dtype: float64

# %%
data
# Out:
#     Year  International Production  Stock  DomesticConsumption  Imports
# 0   1949                     149.3    4.2                108.1     15.9
# 1   1950                     161.2    4.1                114.8     16.4
# 2   1951                     171.5    3.1                123.2     19.0
# 3   1952                     175.5    3.1                126.9     19.1
# 4   1953                     180.8    1.1                132.1     18.8
# 5   1954                     190.7    2.2                137.7     20.4
# 6   1955                     202.1    2.1                146.0     22.7
# 7   1956                     212.4    5.6                154.1     26.5
# 8   1957                     226.1    5.0                162.3     28.1
# 9   1958                     231.9    5.1                164.3     27.6
# 10  1959                     239.0    0.7                167.6     26.3
# 11  1960                     258.0    5.6                176.8     31.1
# ...

# %%
sns.heatmap(data.corr())

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 5 columns):
# Year                        18 non-null int64
# International Production    18 non-null float64
# Stock                       18 non-null float64
# DomesticConsumption         18 non-null float64
# Imports                     18 non-null float64
# dtypes: float64(4), int64(1)
# memory usage: 848.0 bytes

# %%
data.describe()
# Out:
#               Year  International Production      Stock  DomesticConsumption  \
# count    18.000000                 18.000000  18.000000            18.000000
# mean   1957.500000                237.516667   3.677778           167.377778
# std       5.338539                 63.516744   1.741384            41.581056
# min    1949.000000                149.300000   0.700000           108.100000
# 25%    1953.250000                183.275000   2.425000           133.500000
# 50%    1957.500000                229.000000   4.000000           163.300000
# 75%    1961.750000                283.750000   4.900000           196.425000
# max    1966.000000                353.900000   7.000000           242.900000
#
#          Imports
# count  18.000000
# mean   30.077778
# std    12.481306
# min    15.900000
# 25%    19.425000
# 50%    27.050000
# 75%    36.075000
# max    56.600000

# %%
data.index
# Out:
# RangeIndex(start=0, stop=18, step=1)

# %%
data.columns
# Out:
# Index(['Year', 'International Production', 'Stock', 'DomesticConsumption',
#        'Imports'],
#       dtype='object')

# %%
data.values
# Out:
# array([[1.949e+03, 1.493e+02, 4.200e+00, 1.081e+02, 1.590e+01],
#        [1.950e+03, 1.612e+02, 4.100e+00, 1.148e+02, 1.640e+01],
#        [1.951e+03, 1.715e+02, 3.100e+00, 1.232e+02, 1.900e+01],
#        [1.952e+03, 1.755e+02, 3.100e+00, 1.269e+02, 1.910e+01],
#        [1.953e+03, 1.808e+02, 1.100e+00, 1.321e+02, 1.880e+01],
#        [1.954e+03, 1.907e+02, 2.200e+00, 1.377e+02, 2.040e+01],
#        [1.955e+03, 2.021e+02, 2.100e+00, 1.460e+02, 2.270e+01],
#        [1.956e+03, 2.124e+02, 5.600e+00, 1.541e+02, 2.650e+01],
#        [1.957e+03, 2.261e+02, 5.000e+00, 1.623e+02, 2.810e+01],
#        [1.958e+03, 2.319e+02, 5.100e+00, 1.643e+02, 2.760e+01],
#        [1.959e+03, 2.390e+02, 7.000e-01, 1.676e+02, 2.630e+01],
#        [1.960e+03, 2.580e+02, 5.600e+00, 1.768e+02, 3.110e+01],
#        [1.961e+03, 2.698e+02, 3.900e+00, 1.866e+02, 3.330e+01],
#        [1.962e+03, 2.884e+02, 3.100e+00, 1.997e+02, 3.700e+01],
#        [1.963e+03, 3.045e+02, 4.600e+00, 2.139e+02, 4.330e+01],
# ...

# %%
sns.pairplot(data)

# %%
from scipy import stats

# %%
slope,intercept,r_value,p_value,std_err=stats.linregress(data['Year'],data['Imports'])

# %%
slope
# Out:
# 2.2204334365325082

# %%
intercept
# Out:
# -4316.420674234608

# %%
r_value
# Out:
# 0.9497299808725487

# %%
p_value
# Out:
# 1.7505675529789705e-09

# %%
std_err
# Out:
# 0.18298663863424056

# %%
sns.kdeplot(data['Year'])

# %%
sns.kdeplot(data['Imports'])

# %%
plt.figure(figsize=(16,19))
plt.scatter(data['Year'],data['Imports'])
plt.plot(data['Year'],intercept+slope*data['Year'],'r')
plt.xlabel('Year')
plt.ylabel('Imports')
plt.title('imports of french fries')
# Out:
# Text(0.5, 1.0, 'imports of french fries')

# %%
pandas_profiling.ProfileReport(data)
# Out:
#                 <iframe
#                     width="100%"
#                     height="800px"
#                     srcdoc="&lt;!doctype html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
#     &lt;meta charset=&quot;utf-8&quot;&gt;
#     &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;
#     &lt;meta name=&quot;description&quot; content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;
#     &lt;meta name=&quot;author&quot; content=&quot;Jos Polfliet, Simon Brugman and the open source community.&quot;&gt;
#     &lt;meta name=&quot;generator&quot; content=&quot;Pandas Profiling 2.2.0&quot; /&gt;
#     &lt;meta name=&quot;url&quot; content=&quot;https://github.com/pandas-profiling/pandas-profiling&quot;&gt;
#
#     &lt;title&gt;Pandas Profiling Report&lt;/title&gt;
#
# &lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
# ...
