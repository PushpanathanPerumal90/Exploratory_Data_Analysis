# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import pandas_profiling

# %%
"""Problem statement: we have predict the temprature in the groung wweather we can play the match or not when temp is high & perform EDA for each col(Pairplot,scatter,plot,kdeplot) using pandas report & scipy"""
# Out:
# 'Problem statement: we have predict the temprature in the groung wweather we can play the match or not when temp is high & perform EDA for each col(Pairplot,scatter,plot,kdeplot) using pandas report & scipy'

# %%
cricket=pd.read_csv('https://raw.githubusercontent.com/PushpanathanPerumal90/Data-Sets-For-Machine-Learnig-and-Data-Science/master/DataSets/Regression_Data_cricket_chirps.csv')

# %%
cricket
# Out:
#     Chirps/Minute  Temperature
# 0            20.0         88.6
# 1            16.0         71.6
# 2            19.8         93.3
# 3            18.4         84.3
# 4            17.1         80.6
# 5            15.5         75.2
# 6            14.7         69.7
# 7            17.1         82.0
# 8            15.4         69.4
# 9            16.2         83.3
# 10           15.0         79.6
# 11           17.2         82.6
# 12           16.0         80.6
# 13           17.0         83.5
# 14           14.4         76.3

# %%
cricket.head()
# Out:
#    Chirps/Minute  Temperature
# 0           20.0         88.6
# 1           16.0         71.6
# 2           19.8         93.3
# 3           18.4         84.3
# 4           17.1         80.6

# %%
cricket.tail()
# Out:
#     Chirps/Minute  Temperature
# 10           15.0         79.6
# 11           17.2         82.6
# 12           16.0         80.6
# 13           17.0         83.5
# 14           14.4         76.3

# %%
cricket.shape
# Out:
# (15, 2)

# %%
cricket.size
# Out:
# 30

# %%
cricket.ndim
# Out:
# 2

# %%
cricket.describe()
# Out:
#        Chirps/Minute  Temperature
# count      15.000000    15.000000
# mean       16.653333    80.040000
# std         1.702044     6.707331
# min        14.400000    69.400000
# 25%        15.450000    75.750000
# 50%        16.200000    80.600000
# 75%        17.150000    83.400000
# max        20.000000    93.300000

# %%
sns.pairplot(cricket)

# %%
sns.kdeplot(cricket['Chirps/Minute'])

# %%
sns.kdeplot(cricket['Temperature'])

# %%
plt.plot(cricket)

# %%
sns.kdeplot(cricket)
# Out:
# c:\users\hp\appdata\local\programs\python\python37\lib\site-packages\seaborn\distributions.py:679: UserWarning: Passing a 2D dataset for a bivariate plot is deprecated in favor of kdeplot(x, y), and it will cause an error in future versions. Please update your code.
#   warnings.warn(warn_msg, UserWarning)

# %%
plt.figure(figsize=(16,9))
plt.scatter(cricket['Chirps/Minute'],cricket['Temperature'])
plt.xlabel('Chirps/Minute')
plt.ylabel('Temperature')
plt.title('Regression Data for Cricket Chirps')
# Out:
# Text(0.5, 1.0, 'Regression Data for Cricket Chirps')
