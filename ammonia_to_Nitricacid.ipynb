# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
data=pd.read_csv(r'C:\Users\Hp\Desktop\DATASET NEW\Excel\ammonia_to_nitricacid.csv')

# %%
data
# Out:
#     Operation Time  CoolantTemperature  Transformedacid concentration  \
# 0               80                  27                             89
# 1               80                  27                             88
# 2               75                  25                             90
# 3               62                  24                             87
# 4               62                  22                             87
# 5               62                  23                             87
# 6               62                  24                             93
# 7               62                  24                             93
# 8               58                  23                             87
# 9               58                  18                             80
# 10              58                  18                             89
# 11              58                  17                             88
# ...

# %%
data.head()
# Out:
#    Operation Time  CoolantTemperature  Transformedacid concentration  \
# 0              80                  27                             89
# 1              80                  27                             88
# 2              75                  25                             90
# 3              62                  24                             87
# 4              62                  22                             87
#
#    Unprocessedpercentage
# 0                     42
# 1                     37
# 2                     37
# 3                     28
# 4                     18

# %%
data.head(2)
# Out:
#    Operation Time  CoolantTemperature  Transformedacid concentration  \
# 0              80                  27                             89
# 1              80                  27                             88
#
#    Unprocessedpercentage
# 0                     42
# 1                     37

# %%
data.tail()
# Out:
#     Operation Time  CoolantTemperature  Transformedacid concentration  \
# 16              50                  19                             72
# 17              50                  19                             79
# 18              50                  20                             80
# 19              56                  20                             82
# 20              70                  20                             91
#
#     Unprocessedpercentage
# 16                      8
# 17                      8
# 18                      9
# 19                     15
# 20                     15

# %%
data.tail(2)
# Out:
#     Operation Time  CoolantTemperature  Transformedacid concentration  \
# 19              56                  20                             82
# 20              70                  20                             91
#
#     Unprocessedpercentage
# 19                     15
# 20                     15

# %%
data.shape
# Out:
# (21, 4)

# %%
data.size
# Out:
# 84

# %%
data.ndim
# Out:
# 2

# %%
data.describe()
# Out:
#        Operation Time  CoolantTemperature  Transformedacid concentration  \
# count       21.000000           21.000000                      21.000000
# mean        60.428571           21.095238                      86.285714
# std          9.168268            3.160771                       5.358571
# min         50.000000           17.000000                      72.000000
# 25%         56.000000           18.000000                      82.000000
# 50%         58.000000           20.000000                      87.000000
# 75%         62.000000           24.000000                      89.000000
# max         80.000000           27.000000                      93.000000
#
#        Unprocessedpercentage
# count              21.000000
# mean               17.523810
# std                10.171623
# min                 7.000000
# 25%                11.000000
# 50%                15.000000
# 75%                19.000000
# max                42.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 4 columns):
# Operation Time                   21 non-null int64
# CoolantTemperature               21 non-null int64
# Transformedacid concentration    21 non-null int64
# Unprocessedpercentage            21 non-null int64
# dtypes: int64(4)
# memory usage: 800.0 bytes

# %%
sns.kdeplot(data)
# Out:
# c:\users\hp\appdata\local\programs\python\python37\lib\site-packages\seaborn\distributions.py:679: UserWarning: Passing a 2D dataset for a bivariate plot is deprecated in favor of kdeplot(x, y), and it will cause an error in future versions. Please update your code.
#   warnings.warn(warn_msg, UserWarning)

# %%
plt.plot(data)

# %%
data.index
# Out:
# RangeIndex(start=0, stop=21, step=1)

# %%
data.columns
# Out:
# Index(['Operation Time', 'CoolantTemperature', 'Transformedacid concentration',
#        'Unprocessedpercentage'],
#       dtype='object')

# %%
data.values
# Out:
# array([[80, 27, 89, 42],
#        [80, 27, 88, 37],
#        [75, 25, 90, 37],
#        [62, 24, 87, 28],
#        [62, 22, 87, 18],
#        [62, 23, 87, 18],
#        [62, 24, 93, 19],
#        [62, 24, 93, 20],
#        [58, 23, 87, 15],
#        [58, 18, 80, 14],
#        [58, 18, 89, 14],
#        [58, 17, 88, 13],
#        [58, 18, 82, 11],
#        [58, 19, 93, 12],
#        [50, 18, 89,  8],
#        [50, 18, 86,  7],
#        [50, 19, 72,  8],
#        [50, 19, 79,  8],
#        [50, 20, 80,  9],
#        [56, 20, 82, 15],
#        [70, 20, 91, 15]], dtype=int64)

# %%
sns.pairplot(data)

# %%
import pandas_profiling

# %%
pandas_profiling.ProfileReport(data)
# Out:
#                 <iframe
#                     width="100%"
#                     height="800px"
#                     srcdoc="&lt;!doctype html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
#     &lt;meta charset=&quot;utf-8&quot;&gt;
#     &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;
#     &lt;meta name=&quot;description&quot; content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;
#     &lt;meta name=&quot;author&quot; content=&quot;Jos Polfliet, Simon Brugman and the open source community.&quot;&gt;
#     &lt;meta name=&quot;generator&quot; content=&quot;Pandas Profiling 2.2.0&quot; /&gt;
#     &lt;meta name=&quot;url&quot; content=&quot;https://github.com/pandas-profiling/pandas-profiling&quot;&gt;
#
#     &lt;title&gt;Pandas Profiling Report&lt;/title&gt;
#
# &lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
# ...
