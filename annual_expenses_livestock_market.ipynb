# %%
import pandas as pd

# %%
data=pd.read_csv(r'C:\Users\Hp\Desktop\DATASET NEW\Excel\annual_expenses_livestock_market.csv')

# %%
data
# Out:
#     Index  One  Cattle (thousands)  Calves (thousands)  Pigs(thousands)  \
# 0       1    1               3.437               5.791            3.268
# 1       2    1              12.801               4.558            5.751
# 2       3    1               6.136               6.223           15.175
# 3       4    1              11.685               3.212            0.639
# 4       5    1               5.733               3.220            0.534
# 5       6    1               3.021               4.348            0.839
# 6       7    1               1.689               0.634            0.318
# 7       8    1               2.339               1.895            0.610
# 8       9    1               1.025               0.834            0.734
# 9      10    1               2.936               1.419            0.331
# 10     11    1               5.049               4.195            1.589
# 11     12    1               1.693               3.602            0.837
# ...

# %%
data.drop(['Index'],axis=1,inplace=True)
data.drop(['One'],axis=1,inplace=True)

# %%
data.head()
# Out:
#    Cattle (thousands)  Calves (thousands)  Pigs(thousands)  Lambs(thousands)  \
# 0               3.437               5.791            3.268            10.649
# 1              12.801               4.558            5.751            14.375
# 2               6.136               6.223           15.175             2.811
# 3              11.685               3.212            0.639             0.964
# 4               5.733               3.220            0.534             2.052
#
#   Expenses (1000*dollars)
# 0                  27.698
# 1                  57.634
# 2                  47.172
# 3                  49.295
# 4                  24.115

# %%
data.tail()
# Out:
#     Cattle (thousands)  Calves (thousands)  Pigs(thousands)  Lambs(thousands)  \
# 14              14.325               4.300           10.781            36.863
# 15               7.737               9.043            1.394             1.524
# 16               7.538               4.538            2.565             5.109
# 17              10.211               4.994            3.081             3.681
# 18               8.697               3.005            1.378             3.338
#
#    Expenses (1000*dollars)
# 14                 101.334
# 15                  47.427
# 16                  35.944
# 17                  45.945
# 18                   46.89

# %%
data.shape
# Out:
# (19, 5)

# %%
data.size
# Out:
# 95

# %%
data.ndim
# Out:
# 2

# %%
data.isnull().sum()
# Out:
# Cattle (thousands)         0
# Calves (thousands)         0
# Pigs(thousands)            0
# Lambs(thousands)           0
# Expenses (1000*dollars)    0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 5 columns):
# Cattle (thousands)         19 non-null float64
# Calves (thousands)         19 non-null float64
# Pigs(thousands)            19 non-null float64
# Lambs(thousands)           19 non-null float64
# Expenses (1000*dollars)    19 non-null object
# dtypes: float64(4), object(1)
# memory usage: 888.0+ bytes

# %%
data.values
# Out:
# array([[3.437, 5.791, 3.2680000000000002, 10.649000000000001, '27.698'],
#        [12.800999999999998, 4.558, 5.751, 14.375, '57.634'],
#        [6.136, 6.223, 15.175, 2.8110000000000004, '47.172'],
#        [11.685, 3.2119999999999997, 0.639, 0.9640000000000001, '49.295'],
#        [5.733, 3.22, 0.534, 2.052, '24.115'],
#        [3.0210000000000004, 4.348, 0.8390000000000001, 2.356, '33.612'],
#        [1.689, 0.634, 0.318, 2.209, '9.512'],
#        [2.339, 1.895, 0.61, 0.605, '14,755'],
#        [1.025, 0.8340000000000001, 0.7340000000000001, 2.825, '10.57'],
#        [2.9360000000000004, 1.419, 0.331, 0.231, '15.394'],
#        [5.0489999999999995, 4.195, 1.589, 1.9569999999999999, '27.843'],
#        [1.693, 3.602, 0.8370000000000001, 1.5819999999999999, '17.717'],
#        [1.187, 2.679, 0.45899999999999996, 18.837, '20.253'],
#        [9.73, 3.951, 3.78, 0.524, '37.465'],
#        [14.325, 4.3, 10.780999999999999, 36.863, '101.334'],
# ...

# %%
data.columns
# Out:
# Index(['Cattle (thousands)', 'Calves (thousands)', 'Pigs(thousands)',
#        'Lambs(thousands)', 'Expenses (1000*dollars)'],
#       dtype='object')

# %%
data.index
# Out:
# RangeIndex(start=0, stop=19, step=1)

# %%
data.describe()
# Out:
#        Cattle (thousands)  Calves (thousands)  Pigs(thousands)  \
# count           19.000000           19.000000        19.000000
# mean             6.156263            3.812684         2.845421
# std              4.189905            1.990587         3.919962
# min              1.025000            0.634000         0.318000
# 25%              2.637500            2.842000         0.624500
# 50%              5.733000            3.951000         1.378000
# 75%              9.213500            4.548000         3.174500
# max             14.325000            9.043000        15.175000
#
#        Lambs(thousands)
# count         19.000000
# mean           5.920632
# std            9.004095
# min            0.231000
# 25%            1.553000
# 50%            2.356000
# 75%            4.395000
# max           36.863000

# %%
import seaborn as sns

# %%
sns.pairplot(data)

# %%
import pandas_profiling

# %%
pandas_profiling.ProfileReport(data)
# Out:
#                 <iframe
#                     width="100%"
#                     height="800px"
#                     srcdoc="&lt;!doctype html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
#     &lt;meta charset=&quot;utf-8&quot;&gt;
#     &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;
#     &lt;meta name=&quot;description&quot; content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;
#     &lt;meta name=&quot;author&quot; content=&quot;Jos Polfliet, Simon Brugman and the open source community.&quot;&gt;
#     &lt;meta name=&quot;generator&quot; content=&quot;Pandas Profiling 2.2.0&quot; /&gt;
#     &lt;meta name=&quot;url&quot; content=&quot;https://github.com/pandas-profiling/pandas-profiling&quot;&gt;
#
#     &lt;title&gt;Pandas Profiling Report&lt;/title&gt;
#
# &lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
# ...
